# %%
# !git clone https://github.com/hiive/mlrose.git
# Out:
# Cloning into 'mlrose'...

# %%
pip install ./mlrose/
# Out:
# Processing c:\users\zebin\onedrive\csmaster\ml\hw\randomized optimization\mlrose
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.7 MB 435.7 kB/s eta 0:00:04
#    ----------- ---------------------------- 0.5/1.7 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 10.8 MB/s eta 0:00:00
# ...
#   Created wheel for mlrose_hiive: filename=mlrose_hiive-2.2.4-py3-none-any.whl size=105212 sha256=51f157e3a53dc693c1b23e3bde1291aa00dee8fa2c0b97b7c45c5f6dd890ea3d
#   Stored in directory: C:\Users\zebin\AppData\Local\Temp\pip-ephem-wheel-cache-zbd8cvzs\wheels\c8\bf\a8\7a50924b94a1e3b717a6be63c290f3b4b47c0865c289a4035a
# ...

# %%
pip install torch
# Out:
# ...
#    ---------------------------------------- 0.0/159.7 MB ? eta -:--:--
#    ---------------------------------------- 0.4/159.7 MB 9.2 MB/s eta 0:00:18
#     --------------------------------------- 2.1/159.7 MB 26.7 MB/s eta 0:00:06
#    - -------------------------------------- 4.1/159.7 MB 28.7 MB/s eta 0:00:06
#    - -------------------------------------- 5.9/159.7 MB 31.4 MB/s eta 0:00:05
#    - -------------------------------------- 7.4/159.7 MB 31.7 MB/s eta 0:00:05
#    -- ------------------------------------- 9.2/159.7 MB 32.6 MB/s eta 0:00:05
#    -- ------------------------------------- 11.0/159.7 MB 36.4 MB/s eta 0:00:05
#    --- ------------------------------------ 12.9/159.7 MB 36.4 MB/s eta 0:00:05
#    --- ------------------------------------ 14.2/159.7 MB 36.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 16.0/159.7 MB 36.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 18.0/159.7 MB 38.5 MB/s eta 0:00:04
# ...

# %%
pip install -U skorch
# Out:
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/239.4 kB ? eta -:--:--
#    --------------------------------------- 239.4/239.4 kB 14.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
